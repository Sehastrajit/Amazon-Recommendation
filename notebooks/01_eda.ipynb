# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/manyamehta/Desktop/amazon-recommender/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd        # for loading and manipulating data (like Excel in Python)
import numpy as np         # for math operations
import matplotlib.pyplot as plt   # for drawing charts
import gzip                # for reading compressed (.gz) files
import json                # for reading JSON format files
import os                  # for working with file paths

print("All imports successful!")
# Out:
# All imports successful!
